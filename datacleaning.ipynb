# %%
### THIS SCRIPT CLEANS THE COLLECTED DATA AND ORGANZIES MULTIPLE MONGODB-RELATED DATABASE OPERATIONS ###

# %%
import pymongo 
import tqdm
import requests
import json

from bson.objectid import ObjectId
from pprint import pprint

##### INIT GLOBAL VARIABLES#####

#init Mongo
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

#create database
db = client.visualizing_sep

#collection to hold SEP TOC
toc_collection = db.sep_toc_win2019

#collection to hold entry objects
entries_collection = db.sep_entries

#collection to hold InPhO data 
inpho_collection = db.inpho_apidata

# %%
#After downloading all of the JSON data from InPhO and storing it inside the related SEP entry's document, we have to test the downloaded data for any errors or mistakes. 

#First thing to do is identify any records in SEP that didn't have any associated InPho entries.
sep_no_inpho = entries_collection.find( filter={'inpho_api': 'Error: No InPhO entry'},
                                        projection = ['title'],
                                        sort=[('title',1)]
                                        )
list_sep_no_inpho = list(sep_no_inpho)
pprint(list_sep_no_inpho)

#These  14 sep articles didn't link into InPhO at all. I went into InPhO and found the appropriate API endpoint for those, and indicated the URL for those articles that do have InPhO entries. Not all of them had InPhO entries though.

# 'Algebraic Propositional Logic', inpho: idea/6267
#  'Basil [Cardinal] Bessarion'}, thinker/6297
# {'title': 'Dynamic Epistemic Logic'}, idea/5642
# {'title': 'Hegel’s Dialectics'}, NONE
# {'title': 'Ibn Sina [Avicenna]'}, thinker/2577
# {'title': 'Ibn Sina’s Natural Philosophy'}, NONE
# {'title': 'Identity and Individuality in Quantum Theory'}, idea/1191
# {'title': 'Legalism in Chinese Philosophy'}, idea/5595
# {'title': 'Martin Buber'}, thinker/2718
# {'title': 'Mental Causation'}, idea/1240
# {'title': 'Nietzsche’s Life and Works'} NONE,
# {'title': 'Religious Daoism'}, idea/5663
# {'title': 'Sophie de Grouchy'}, NONE
# {'title': 'Supererogation'}] idea/1128.html
# Out:
# [{'_id':ObjectId('5e82960380ca4dfd7911cf52'),
# 'title':'Dynamic Epistemic Logic'},
# {'_id': ObjectId('5e8298d880ca4dfd7911d03e'), 'title': 'Hegel’s Dialectics'},
# {'_id': ObjectId('5e82997680ca4dfd7911d06f'), 'title': 'Ibn Sina [Avicenna]'},
# {'_id':ObjectId('5e82997380ca4dfd7911d06e'),
# 'title':'Ibn Sina’s Natural Philosophy'},
# {'_id':ObjectId('5e83953742ea6bed61c10a80'),
# 'title':'Identity and Individuality in Quantum Theory'},
# {'_id':ObjectId('5e8293a180ca4dfd7911ce8d'),
# 'title':'Legalism in Chinese Philosophy'},
# {'_id': ObjectId('5e8292f980ca4dfd7911ce61'), 'title': 'Martin Buber'},
# {'_id': ObjectId('5e829c6580ca4dfd7911d1a4'), 'title': 'Mental Causation'},
# {'_id':ObjectId('5e8392bc42ea6bed61c109b5'),
# 'title':'Nietzsche’s Life and Works'},
# {'_id': ObjectId('5e82951180ca4dfd7911cf02'), 'title': 'Religious Daoism'},
# {'_id': ObjectId('5e83977c42ea6bed61c10b33'), 'title': 'Sophie de Grouchy'},
# {'_id': ObjectId('5e83980e42ea6bed61c10b61'), 'title': 'Supererogation'}]

# %%
#make a list of apropriate endpionts, and use 0 to indicate those without endpoints. These are sorted in the same order as the entries.
inpho_apis = [  'idea/6267',
                'thinker/6297',
                'idea/5642',0,
                'thinker/2577',0,
                'idea/1191', 
                'idea/5595',
                'thinker/2718',
                'idea/1240',0,
                'idea/5663',0,
                'idea/1128' ]

#zip mongo projection and new endpoints together
zipped_sep_inpho = zip(list_sep_no_inpho[0:2],inpho_apis[0:2])

# %%
def update_sep_json(id_value,api_endpoint):
    inpho_api = f'http://inpho.cogs.indiana.edu/{api_endpoint}.json'
    print(inpho_api)
    request_inpho = requests.get(inpho_api)
    inpho_json = json.loads(request_inpho.text)

    new_values = {
        'inpho_api': inpho_api,
        'inpho_json': inpho_json
    }

    entries_collection.update_one(
        { '_id': ObjectId(id_value) },
        { '$set': new_val}
    )

    # boolean confirmation that the API call went through
    print ("acknowledged:", result.acknowledged)

# %%
# for zipped in zipped_sep_inpho:
#     mongoid = zipped[0]['_id']
#     mongotitle = zipped[0]['title']
#     api_end = zipped[1]
#     update_sep_json(mongoid,api_end)
# Out:
# acknowledged:True

# %%
update_sep_json('5e829b4d80ca4dfd7911d12e','idea/6267')
# Out:
# acknowledged:True

# %%
doc = list(entries_collection.find(
    filter={'_id': ObjectId('5e829b4d80ca4dfd7911d12e')},
    projection=['inpho_api','inpho_json','title']
    ))

print(doc)
# Out:
# [{'_id': ObjectId('5e829b4d80ca4dfd7911d12e'), 'title': 'Algebraic Propositional Logic', 'inpho_api': 'testing insert', 'inpho_json': 'Error: No InPhO entry'}]

# %%
# Move the JSON data for each SEP entry into its own collection. We do this because we want to download additional API data from InPhO for those entities that are NOT in SEP. This will give us a broader picture of the history of philosophy than simply what exists in SEP.
 
#HOWEVER: we also have to clean up the JSON. In 95 cases, the JSON data from InPhO was structured slightly different, in that those data were wrapped inside ["responseData"]["result"] keys, when the rest of the data was not. We want to create a uniform dataset, so we remove ["responseData"]["result"] from those data so that every InPhO object has the same structure. 

#get all SEP entries
sep_entries = list(entries_collection.find({}))

for entry in sep_entries:
    #get "inpho_json" object from SEP
    json_data = entry['inpho_json']

    #some SEP entries didn't have an InPhO reference, so we note that here.
    if json_data == 'Error: No InPhO entry':
        final_json_data = {'Error': 'No InhPhoEntry'}

    #process main data elements
    else:
        if 'responseData' in json_data:
            #if ["responseData"]["result"] in current object, pull the child references from it
            final_json_data = json_data["responseData"]["result"]
        else:
            #all good here
             final_json_data = json_data

    inpho_collection.insert_one(final_json_data)

# %%
#get counts of different aspects of the the dataset
count_ids = inpho_collection.count_documents({'ID': {'$exists': True}})
distinct_ids = inpho_collection.distinct('ID')

print(count_ids)
print(len(distinct_ids))
# Out:
# 1657
# 1656

# %%
dups = inpho_collection.aggregate([
    {"$match": {"ID" :{ "$exists" : True } } }, 
    {"$group" : {"_id": "$ID", "count": { "$sum": 1 } } },
    {"$match": {"count" : {"$gt": 1} } } 
    # {"$project": {"ID" : "$_id", "_id" : 0} }
])

for dup in dups:
    print(dup)
# Out:
# {'_id': 3563, 'count': 2}

# %%
dup_entry = inpho_collection.find_one({'ID':3563})
print(dup_entry)
# Out:
# {'_id': ObjectId('5e8e5db82763be045e93e73c'), 'wiki': 'Mencius', 'influenced': [], 'death': [{'month': 0, 'day': 0, 'year': 372}], 'teachers': [], 'url': '/thinker/3563', 'influenced_by': [2844], 'professions': [], 'death_strings': ['372'], 'related_thinkers': [2844, 4203, 4195, 4173, 4092, 4192, 3060, 2633, 3345], 'sep_dir': 'mencius', 'students': [], 'birth_strings': ['November 372'], 'birth': [{'month': 11, 'day': 0, 'year': 372}], 'nationalities': ['Chinese'], 'related_ideas': [1694, 1544, 1343, 1695, 148, 1130, 352, 1527, 5338], 'label': 'Mencius', 'type': 'thinker', 'ID': 3563, 'aliases': []}

# %%
entries_collection.count_documents({'inpho_json.label': {'$regex': 'Mencius'}})
mencius_entries = entries_collection.find({'inpho_json.label': {'$regex': 'Mencius'}})
for entry in mencius_entries:
    pprint(entry)
# Out:
# er, Zhu Xi, following the interpretation of Cheng Yi, '
# 'claims\n'
# 'that\n'
# '\n'
# '…what is meant by “extending knowledge lies in ge\n'
# 'wu” is that desiring to extend my knowledge lies in\n'
# 'encountering things and exhaustively investigating their '
# 'Pattern.  In\n'
# 'general, the human mind is sentient and never fails to have '
# 'knowledge,\n'
# 'while the things of the world never fail to have the Pattern.  '
# 'It is\n'
# 'only because the Pattern is not yet exhaustively investigated '
# 'that\n'
# 'knowledge is not fully fathomed.  Consequently, at the beginning '
# 'of\n'
# 'education in the Great Learning, the learner must be made to '
# 'encounter\n'
# 'the things of the world, and never fail to follow the Pattern '
# 'that one\n'
# 'already knows and further exhaust it, seeking to arrive at the\n'
# 'farthest points.  When one has exerted effort for a long time, '
# 'one\n'
# 'day, like something suddenly cracking open, one will know in a '
# 'manner\n'
# 'that binds it all together. (Translation slightly modified from '
# 'Tiwald\n'
# 'and Van Norden 2014, 191)\n'
# '\n'
# 'Following Zhu Xi’s interpretations, most translators today '
# 'render\n'
# 'ge wu as “investigating things.” Wang and his\n'
# 'friend Qian were trying to “investigate things” in this\n'
# 'manner when they stared attentively at the bamboos, struggling '
# 'to\n'
# 'grasp their underlying Pattern.  It is questionable, though, '
# 'whether\n'
# 'this is what Zhu Xi had in mind.  Zhu certainly thought the '
# 'Pattern\n'
# 'was present in everything, and could potentially be investigated '
# 'in\n'
# 'even the most mundane of objects.  However, he emphasized that '
# 'the\n'
# 'best method to learn about the Pattern was through studying the\n'
# 'classics texts of Confucianism, particularly the Four Books.  \n'
# 'As important as learning was for Zhu Xi, he stressed that it '
# 'was\n'
# 'possible to know what is right and wrong yet not act on it:\n'
# '“Knowledge and action always need each other.  It’s like how\n'
# 'eyes cannot walk without feet, but feet cannot see without '
# 'eyes.  If\n'
# 'we discuss them in terms of their sequence, knowledge comes '
# 'first.\n'
# 'But if we discuss them in terms of importance, action is what '
# 'is\n'
# 'important” (Tiwald and Van Norden 2014, 180–81).  What\n'
# 'connects knowledge and action, on Zhu Xi’s account, is '
# 'Sincerity.\n'
# 'Sincerity (chéng) is a subtle and multifaceted notion\n'
# 'in Neo–Confucian thought.  However, the Great Learning\n'
# 'focuses on one key aspect of it: “What is meant by ‘making\n'
# 'thoughts have Sincerity’ is to let there be no self–deception.\n'
# 'It is like hating a hateful odor, or loving a lovely sight.  The '
# 'is\n'
# 'called not being conflicted” (Tiwald and Van Norden 2014, 191).\n'
# 'In other words, humans engage in wrongdoing through a sort of\n'
# 'self–deception in which they allow themselves to ignore the\n'
# 'promptings of their moral sense, and become motivated solely by '
# 'their\n'
# 'physical desires for sex, food, wealth, etc.  Once one knows '
# 'what is\n'
# 'right and wrong, one must then make an effort to keep that '
# 'knowledge\n'
# 'present to one’s consciousness, so that it becomes '
# 'motivationally\n'
# 'efficacious.  As Zhu Xi explains, “…those who desire to\n'
# 'cultivate themselves, when they know to do good in order to '
# 'avoid the\n'
# 'bad, must then genuinely make an effort and forbid\n'
# 'self–deception, making their hatred of the [ethically] hateful\n'
# 'be like their hating a hateful odor, and their loving what is '
# 'good\n'
# 'like their loving a lovely sight” (Tiwald and Van Norden 2014,\n'
# '192).  \n'
# 'Wang challenged almost every aspect of Zhu Xi’s interpretation '
# 'of\n'
# 'the Great Learning. He regarded Zhu Xi’s account as not just\n'
# 'theoretically mistaken but dangerously misleading for those '
# 'seeking to\n'
# 'improve themselves ethically.  However, Wang recognized that '
# 'students\n'
# 'who had memorized Zhu Xi’s interpretation to prepare for the '
# 'civil\n'
# 'service examinations would have difficulty understanding the '
# 'text any\n'
# 'other way.  Consequently, when he accepted a new disciple, Wang '
# 'often\n'
# 'began by explaining his alternative interpretation of the Great\n'
# 'Learning, and invited students to ask questions.  Wang’s '
# 'approach\n'
# 'is preserved in a brief but densely argued work, “Questions on\n'
# 'the Great Learning.” Let’s begin at the apparent\n'
# 'foundation of the Great Learning’s program: ge wu.\n'
# 'Whereas Zhu Xi argues that ge wu is literally “reaching\n'
# 'things,” meaning to intellectually grasp the Pattern in things\n'
# 'and situations, Wang argues that ge wu means\n'
# '“rectifying things,” including both one’s own thoughts and\n'
# 'the objects of those thoughts.  For Zhu Xi, ge wu is\n'
# 'primarily about gaining knowledge, while for Wang it is about\n'
# 'motivation and \n'
# 'action.[8] \n'
# 'The fact that the Great Learning explicates ge wu\n'
# 'in terms of “extending knowledge” might seem to support\n'
# 'Zhu Xi’s interpretation.  However, Wang offers a plausible '
# 'alternative\n'
# 'explanation: “To fully extend one’s knowledge is not like the\n'
# 'so–called ‘filling out’ of what one knows that later\n'
# 'scholars [like Zhu Xi] talk about. It is simply to extend fully '
# 'the\n'
# '‘pure knowing’ of my own mind.  Pure knowing is what\n'
# '[Mencius] was talking about when he said that all humans have\n'
# '‘the mind of approval and disapproval.’ The mind of\n'
# 'approval and disapproval ‘knows without pondering’ and is\n'
# '‘capable without learning’\u2009” (Tiwald and Van\n'
# 'Norden 2014, 248, glosses \n'
# 'mine).[9]\n'
# ' Wang is suggesting that “extending\n'
# 'knowledge” refers simply to exercising our innate faculty of\n'
# 'moral awareness, which Mencius refers to as “pure\n'
# 'knowing.” As David S. Nivison explains, “We might say that\n'
# 'Wang’s ‘extending’ of knowledge is more like extending\n'
# 'one’s arm than, say, extending one’s vocabulary” (Nivison '
# '1996a,\n'
# '225).\n'
# 'According to Zhu Xi, the opening of the Great Learning\n'
# 'lists a series of steps that are, at least to some extent, '
# 'temporally\n'
# 'distinct. Wang demurs:\n'
# '\n'
# 'While one can say that there is an ordering of first and last in '
# 'this\n'
# 'sequence of spiritual training, the training itself is a unified '
# 'whole\n'
# 'that cannot be divided into any ordering of first and last.  '
# 'While\n'
# 'this sequence of spiritual training cannot be divided into any\n'
# 'ordering of first and last, only when every aspect of its '
# 'practice is\n'
# 'highly refined can one be sure that it will not be deficient in '
# 'the\n'
# 'slightest degree. (Tiwald and Van Norden 2014, 250)\n'
# '\n'
# '\n'
# 'Wang’s argument here is similar to the one he made about the '
# 'verbal\n'
# 'distinction between knowing and acting (Section 3, above). He '
# 'claimed\n'
# 'that the ancient sages recognized that knowing and acting were\n'
# 'ultimately one thing, but sometimes discussed them separately '
# 'for\n'
# 'pedagogic purposes, to help those who underemphasized one aspect '
# 'of\n'
# 'this unity.  Similarly, Wang suggests, the Great Learning\n'
# 'uses multiple terms to describe various aspects of the unified\n'
# 'exercise of moral agency, but does not mean to suggest that '
# 'these are\n'
# 'actually distinct temporal stages:\n'
# '\n'
# '…we can say that “self,” “mind,”\n'
# '“thoughts,” “knowledge,” and\n'
# '“things” describe the sequence of spiritual training.\n'
# 'While each has its own place, in reality they are but a single '
# 'thing.\n'
# 'We can say that “ge wu,” “extending,”\n'
# '“making Sincere,” “correcting,” and\n'
# '“cultivating” describe the spiritual training used in the\n'
# 'course of this sequence.  While each has its own name, in '
# 'reality they\n'
# 'are but a single affair.  What do we mean by “self”?  It\n'
# 'is the way we refer to the physical operations of the mind.  '
# 'What do\n'
# 'we mean by “mind”? It is the way we refer to the luminous\n'
# 'and intelligent master of the person. (Translation slightly '
# 'modified\n'
# 'from Tiwald and Van Norden 2014, 247)\n'
# '\n'
# 'Wang even interprets the key metaphor of the Great\n'
# 'Learning in a very different way from Zhu Xi.  For Zhu Xi, '
# 'hating\n'
# 'evil “like hating a hateful odor,” and loving good\n'
# '“like loving a lovely sight” are goals that we must aspire\n'
# 'to, but can only achieve after an arduous process of ethical\n'
# 'cultivation.  For Wang Yangming, these phrases describe what '
# 'our\n'
# 'attitudes toward good and evil can and should be at the very '
# 'inception\n'
# 'of ethical cultivation:\n'
# '\n'
# '…the Great Learning gives us examples of true knowing\n'
# 'and acting, saying it is “like loving a lovely sight” or\n'
# '“hating a hateful odor.” Seeing a lovely sight is a case\n'
# 'of knowing, while loving a lovely sight is a case of acting.  As '
# 'soon\n'
# 'as one sees that lovely sight, one naturally loves it.  It is '
# 'not as\n'
# 'if you first see it and only then, intentionally, you decide to '
# 'love\n'
# 'it.  Smelling a hateful odor is a case of knowing, while hating '
# 'a\n'
# 'hateful odor is a case of acting.  As soon as one smells that '
# 'hateful\n'
# 'odor, one naturally hates it.  It is not as if you first smell '
# 'it and\n'
# 'only then, intentionally, you decide to hate it.  Consider the '
# 'case of\n'
# 'a person with a stuffed–up nose.  Even if he sees a malodorous\n'
# 'object right in front of him, the smell does not reach him, and '
# 'so he\n'
# 'does not hate it.  This is simply not to know the hateful\n'
# 'odor. (Tiwald and Van Norden 2014, 267)\n'
# '\n'
# 'In summary, Zhu Xi and Wang agree that the Great Learning\n'
# 'is an authoritative statement on ethical cultivation, expressing '
# 'the\n'
# 'wisdom of the ancient sages.  However, for Zhu Xi, it is '
# 'analogous to\n'
# 'a recipe, with distinct steps that must be performed in order.  '
# 'For\n'
# 'Wang, the Great Learning is analogous to a description of a\n'
# 'painting, in which shading, coloring, composition, perspective '
# 'and\n'
# 'other factors are aspects of a unified effect.  \n'
# '5. Metaphysics\n'
# 'Wang was not primarily interested in theoretical issues.  '
# 'However,\n'
# 'some of his comments suggest a subtle metaphysical view that '
# 'supports\n'
# 'his conception of ethics.  This metaphysics is phrased in terms '
# 'of the\n'
# 'Pattern/qi framework (see Section 2, above), and also makes\n'
# 'use of the Substance/Function distinction.  Substance\n'
# '(tǐ), literally body, is an entity in itself, while\n'
# 'Function is its characteristic or appropriate activity or\n'
# 'manifestation: a lamp is Substance, its light is function; an '
# 'eye is\n'
# 'Substance, seeing is its Function; water is Substance, waves are '
# 'its\n'
# 'Function.  The Substance/Function distinction goes back to the '
# 'Daoists\n'
# 'of the Han dynasty (202 BCE–220 CE) and became central among\n'
# 'Chinese Buddhists before being picked up by Neo–Confucians.\n'
# 'Part of the attraction of this vocabulary is that it gives\n'
# 'philosophers drawn to a sort of monism the ability to '
# 'distinguish\n'
# 'between two aspects of what they regard as ultimately a '
# 'unity.  \n'
# 'Wang argues that the human mind is identical with the Pattern '
# 'of\n'
# 'the universe, and as such it forms “one body”\n'
# '(yì tǐ, one Substance) with “Heaven, Earth,\n'
# 'and the myriad creatures” of the world.  The difference between\n'
# 'the virtuous and the vicious is that the former recognize that '
# 'their\n'
# 'minds form one body with everything else, while the latter,\n'
# '“because of the space between their own physical form and those\n'
# 'of others, regard themselves as separate” (Tiwald and Van '
# 'Norden\n'
# '2014, 241).  As evidence for the claim that the minds of all '
# 'humans\n'
# 'form one body with the rest of the universe, Wang appeals to a '
# 'thought\n'
# 'experiment first formulated by Mencius: “when they see a child\n'
# '[about to] fall into a well, [humans] cannot avoid having a mind '
# 'of\n'
# 'alarm and compassion for the child” (Tiwald and Van Norden '
# '2014,\n'
# '241–242; Mengzi 2A6).  Wang then anticipates a series\n'
# 'of objections, and offers further thought experiments to '
# 'motivate the\n'
# 'conclusion that only some underlying metaphysical identity '
# 'between\n'
# 'humans and other things can account for the broad range of our\n'
# 'reactions to them:\n'
# '\n'
# 'Someone might object that this response is because the child '
# 'belongs\n'
# 'to the same species.  But when they hear the anguished cries or '
# 'see\n'
# 'the frightened appearance of birds or beasts, they cannot avoid '
# 'a\n'
# 'sense of being unable to bear it. … Someone might object this\n'
# 'this response is because birds and beasts are sentient '
# 'creatures.  But\n'
# 'when they see grass or trees uprooted and torn apart, they '
# 'cannot\n'
# 'avoid feeling a sense of sympathy and distress. … Someone might\n'
# 'object that this response is because grass and trees have life '
# 'and\n'
# 'vitality.  But when they see tiles and stones broken and '
# 'destroyed,\n'
# 'they cannot avoid feeling a sense of concern and regret. … This\n'
# 'shows that the benevolence that forms one body [with Heaven, '
# 'Earth,\n'
# 'and the myriad creatures] is something that even the minds of '
# 'petty\n'
# 'people possess. (Tiwald and Van Norden 2014, 242)\n'
# '\n'
# 'Wang’s first three thought experiments seem fairly compelling '
# 'at\n'
# 'first glance.  Almost all humans would, at least as a first '
# 'instinct,\n'
# 'have “alarm and compassion” if suddenly confronted with\n'
# 'the sight of a child about to fall into a well. In addition, '
# 'humans\n'
# 'often do show pity for the suffering of non–human animals.\n'
# 'Finally, the fact that humans maintain public parks and '
# 'personal\n'
# 'gardens shows some kind of concern for plants.  \n'
# 'It is not a decisive objection to Wang’s view that humans often\n'
# 'fail to manifest benevolence to other humans, non–human '
# 'animals,\n'
# 'or plants.  Wang is arguing that all humans manifest these '
# 'responses\n'
# 'sometimes (and that this is best explained by his favored\n'
# 'metaphysics).  Like all Neo–Confucians, Wang readily\n'
# 'acknowledges that selfish desires frequently block the '
# 'manifestation\n'
# 'of our shared nature.  However, there are three lines of '
# 'objection to\n'
# 'Wang’s view that are harder to dismiss.  (1) There is '
# 'considerable\n'
# 'empirical evidence that some humans never manifest any\n'
# 'compassion for the suffering of others.  In the technical '
# 'literature\n'
# 'of psychology, these people are a subset of those identified as '
# 'having\n'
# '“Antisocial Personality Disorder” as defined in\n'
# ' DSM–V.[10]\n'
# ' (2) Wang asserts that when humans “see tiles and stones broken\n'
# 'and destroyed, they cannot avoid feeling a sense of concern and\n'
# 'regret.” This claim is important for Wang’s argument, because '
# 'he\n'
# 'takes this reaction to be evidence for the conclusion that our '
# 'minds\n'
# 'are ultimately “one Substance” with everything in\n'
# 'the universe, not merely with members of our species, or other\n'
# 'sentient creatures, or other living things.  We can perhaps '
# 'motivate\n'
# 'Wang’s intuition by considering how we might react if we saw '
# 'that\n'
# 'someone had spray painted graffiti on Half Dome in Yosemite '
# 'National\n'
# 'Park.  The defacement of this scenic beauty would probably '
# 'provoke\n'
# 'sadness in those of us with an eye for natural beauty.  However, '
# 'it is\n'
# 'certainly not obvious that everyone manifests even sporadic '
# 'concern\n'
# 'for “tiles and stones,” which is what he needs for his\n'
# 'conclusion. (3) Even if we grant Wang his intuitions, it is not '
# 'clear\n'
# 'that the particular metaphysics he appeals to is the best '
# 'explanation\n'
# 'of those intuitions.  As Darwin himself suggested, our '
# 'compassion for\n'
# 'other humans can be explained in evolutionary terms.  In '
# 'addition, the\n'
# '“biophilia hypothesis” (Wilson [1984]) provides an\n'
# 'evolutionary explanation for the human fondness for other '
# 'animals and\n'
# 'plants.  There is not an obvious evolutionary explanation for '
# 'why\n'
# 'humans seem engaged by non–living natural beauty, like mountain\n'
# 'peaks, but as we have seen it seems questionable how common this '
# 'trait\n'
# 'is.\n'
# '6. Influence \n'
# 'Wang is regarded, along with Lu Xiangshan, as one of the '
# 'founders\n'
# 'of the Lu–Wang School of Neo–Confucianism, or the School\n'
# 'of Mind.  This is one of the two major wings of\n'
# 'Neo–Confucianism, along with the Cheng–Zhu School (named\n'
# 'after Cheng Yi and Zhu Xi), or School of Pattern.  He has '
# 'frequently\n'
# 'been an inspiration for critics of the orthodox Cheng–Zhu\n'
# 'School, not just in China but also in Japan.  In Japan, his '
# 'philosophy\n'
# 'is referred to as Ōyōmeigaku, and its major\n'
# 'adherents included Nakae Tōju (1608–1648) and Kumazawa\n'
# 'Banzan (1619–1691).  Wang’s thought was also an inspiration for\n'
# 'some of the leaders of the Meiji Restoration (1868), which '
# 'began\n'
# 'Japan’s rapid \n'
# 'modernization.[11]\n'
# 'In China, Confucianism underwent a significant shift during the\n'
# 'Qing dynasty (1644–1911) with the development of the Evidential\n'
# 'Research movement.  Evidential Research emphasized carefully\n'
# 'documented and tightly argued work on concrete issues of '
# 'philology,\n'
# 'history, and even mathematics and civil engineering.  Such '
# 'scholars\n'
# 'generally looked with disdain on “the Song–Ming\n'
# 'Confucians” (including both Zhu Xi and Wang Yangming), whom '
# 'they\n'
# 'accused of producing “empty words” that could not be\n'
# ' substantiated.[12] \n'
# ' One of the few Evidential Research\n'
# 'scholars with a serious interest in ethics was Dai Zhen\n'
# '(1724–1777). However, he too was critical of both the\n'
# 'Cheng–Zhu and the Lu–Wang schools.  The three major prongs\n'
# 'of Dai’s critique of Neo–Confucians like Wang were that they '
# '(1)\n'
# 'encouraged people to treat their subjective opinions as the\n'
# 'deliverances of some infallible moral sense, (2) projected\n'
# 'Buddhist–inspired concepts back onto the ancient Confucian\n'
# 'classics, and (3) ignored the ethical value of ordinary '
# 'physical\n'
# 'desires. \n'
# 'One of the major trends in contemporary Chinese philosophy is\n'
# '“New Confucianism.” New Confucianism is a movement to\n'
# 'adapt Confucianism to modern thought, showing how it is '
# 'consistent\n'
# 'with democracy and modern science.  New Confucianism is distinct '
# 'from\n'
# 'what we in the West call Neo–Confucianism, but it adopts many\n'
# 'Neo–Confucian concepts, in particular the view that humans '
# 'share\n'
# 'a trans–personal nature which is constituted by the universal\n'
# 'Pattern.  Many New Confucians agree with Mou Zongsan '
# '(1909–1995)\n'
# 'that Wang had a deeper and more orthodox understanding of '
# 'Confucianism\n'
# 'than did Zhu \n'
# 'Xi.[13] \n'
# 'Wang’s philosophy is of considerable intrinsic interest, because '
# 'of\n'
# 'the ingenuity of his arguments, the systematicity of his views, '
# 'and\n'
# 'the precision of his textual exegesis.  Beyond that, Wang’s work '
# 'has\n'
# 'the potential to inform contemporary ethics. Although his '
# 'particular\n'
# 'metaphysics may not be appealing, many of his ideas can be\n'
# 'naturalized.  It may be hard to believe that everything is '
# 'unified by\n'
# 'a shared, underlying Pattern, but it does seem plausible that we '
# 'are\n'
# 'deeply dependent upon one another and upon our natural '
# 'environment for\n'
# 'our survival and our identities.  I am a husband, a father, a '
# 'teacher,\n'
# 'and a researcher, but only because I have a wife, children, '
# 'students,\n'
# 'and colleagues.  In some sense, we do form “one body” with\n'
# 'others, and Wang provides provocative ideas about how we should\n'
# 'respond to this insight.  In addition, Wang’s fundamental '
# 'criticism of\n'
# 'Zhu Xi’s approach, that it produces pedants who only study and '
# 'talk\n'
# 'about ethics, rather than people who strive to actually be\n'
# 'ethical, has considerable contemporary relevance, particularly '
# 'given\n'
# 'the empirical evidence that our current practices of ethical '
# 'education\n'
# 'have little positive effect on ethical behavior (Schwitzgebel '
# 'and Rust\n'
# '2014; and cf. Schwitzgebel 2013 (Other Internet Resources)).\n',
# 'pubdate':'First published Fri Jul 11, 2014; substantive revision Fri Sep 6, '
# '2019',
# 'title':'Wang Yangming'}

# %%
#count docs between collections 

sep_yes = entries_collection.count_documents({'inpho_json.ID': {'$exists': True}})
inp_yes = inpho_collection.count_documents({'ID': {'$exists': True}})
sep_no = entries_collection.count_documents({'inpho_json.ID': {'$exists': False}})
inp_no = inpho_collection.count_documents({'inpho_json.ID': {'$exists': False}})
sep_error = entries_collection.count_documents({'inpho_json': 'Error: No InPhO entry'})
sep_noerror = entries_collection.count_documents({'inpho_json': {'$ne': 'Error: No InPhO entry'}})
inp_error = inpho_collection.count_documents({'inpho_json': 'Error: No InPhO entry'})
inp_noerror = inpho_collection.count_documents({'inpho_json': {'$ne': 'Error: No InPhO entry'}})
print(sep_yes)
print(sep_no)
print(inp_yes)
print(inp_no)
print(sep_error)
print(sep_noerror)
print(inp_error)
print(inp_noerror)
# Out:
# 1562
# 109
# 0
# 1671
# 14
# 1657
# 0
# 1671
